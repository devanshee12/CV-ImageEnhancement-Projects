# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the uploaded image
image_path = "/content/download.jpeg"
image = cv2.imread(image_path)

# Convert to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply Otsu's thresholding for segmentation
_, segmented = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

# Save the segmented image as a PGM file
pgm_path = "/mnt/data/segmented.pgm"
cv2.imwrite(pgm_path, segmented)

# Display the original and segmented images
fig, axes = plt.subplots(1, 2, figsize=(10, 5))
axes[0].imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
axes[0].set_title("Original Image")
axes[0].axis("off")

axes[1].imshow(segmented, cmap="gray")
axes[1].set_title("Segmented Image")
axes[1].axis("off")

# Save the output screenshot
screenshot_path = "/mnt/data/segmentation_result.png"
plt.savefig(screenshot_path)

# Show the result
plt.show()

# Provide download links
pgm_path, screenshot_path
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-939f787ea4c5> in <cell line: 0>()
#      29 # Save the output screenshot
#      30 screenshot_path = "/mnt/data/segmentation_result.png"
# ---> 31 plt.savefig(screenshot_path)
#      32
#      33 # Show the result
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#    1241     # savefig default implementation has no return, so mypy is unhappy
#    1242     # presumably this is here because subclasses can return?
# -> 1243     res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1244     fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1245     return res
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    3488                 for ax in self.axes:
# ...
